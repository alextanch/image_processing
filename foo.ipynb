# %% [markdown]
# <a href="https://colab.research.google.com/github/alextanch/image_processing/blob/main/foo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh jupyter_bokeh bokeh_sampledata hide_code
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !jupyter nbextension install --py hide_code
# !jupyter nbextension enable --py hide_code
# !jupyter serverextension enable --py hide_code
# Out:
# Installing /usr/local/lib/python3.11/dist-packages/hide_code/ -> hide_code
# Making directory: /usr/local/share/jupyter/nbextensions/hide_code/
# Copying: /usr/local/lib/python3.11/dist-packages/hide_code/hide_code_latex_exporter.py -> /usr/local/share/jupyter/nbextensions/hide_code/hide_code_latex_exporter.py
# Copying: /usr/local/lib/python3.11/dist-packages/hide_code/hide_code_pdf_exporter.py -> /usr/local/share/jupyter/nbextensions/hide_code/hide_code_pdf_exporter.py
# Copying: /usr/local/lib/python3.11/dist-packages/hide_code/hide_code_html_exporter.py -> /usr/local/share/jupyter/nbextensions/hide_code/hide_code_html_exporter.py
# Copying: /usr/local/lib/python3.11/dist-packages/hide_code/hide_code_config.py -> /usr/local/share/jupyter/nbextensions/hide_code/hide_code_config.py
# Copying: /usr/local/lib/python3.11/dist-packages/hide_code/hide_code_preprocessor.py -> /usr/local/share/jupyter/nbextensions/hide_code/hide_code_preprocessor.py
# ...

# %% [markdown]
# $$
#   a_{ij}
# $$

# %%
from bokeh.io import output_notebook
output_notebook()

# %%
# @title
# create a complex chart with mouse-over tooltips

from bokeh.palettes import HighContrast3
from bokeh.plotting import figure, show

fruits = ["Apples", "Pears", "Nectarines", "Plums", "Grapes", "Strawberries"]
years = ["2015", "2016", "2017"]

data = {
    "fruits": fruits,
    "2015": [2, 1, 4, 3, 2, 4],
    "2016": [5, 3, 4, 2, 4, 6],
    "2017": [3, 2, 4, 4, 5, 3]
}

p = figure(
    x_range=fruits,
    height=250,
    title="Fruit Counts by Year",
    toolbar_location=None,
    tools="hover",
    tooltips="$name @fruits: @$name"
)

p.vbar_stack(years, x="fruits", width=0.9, color=HighContrast3, source=data, legend_label=years)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div id="ddedcee6-2c35-45ef-bcc1-c9408613a0cd" data-root-id="p1001" style="display: contents;"></div>
